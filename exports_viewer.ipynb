# %%
import pandas as pd

# %%
csv_path = r"data/"
csv_name = "exerWatch-20250202_1612271076352245711226980.csv"

df = pd.read_csv(csv_path+csv_name)
print(df.columns)
display(df.gyrX.plot())
display(df.gyrY.plot())
display(df.gyrZ.plot())
# Out:
# Index(['index', 'time', 'accX', 'accY', 'accZ', 'gyrX', 'gyrY', 'gyrZ'], dtype='object')
# <Axes: >

# %%
df.gyro_y.plot()

# %%
df.gyro_z.plot()
